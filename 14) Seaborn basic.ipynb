# %% [markdown]
# # Seamborn
# - It is the python libreary used to makr the beautiful chats and graph
# - It helps us to see the patterns and understand the data very easily
# - It is built top non the matplotlib(it is more powerful)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - Uni-variyant analysis

# %%
data = pd.read_excel(r"C:\Users\bhask\Downloads\data.xlsx")
data.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
v1 = sns.displot(data['InternetUsers'])
plt.show()

# %%
v2 = sns.distplot(data['InternetUsers'], bin)
plt.show()

# %% [markdown]
# - Bi-variyant analysis

# %%
v3 = sns.boxplot(data = data, x = "IncomeGroup", y = "BirthRate")
plt.show()

# %%
v3 = sns.lmplot(data = data, x = "InternetUsers", y = "BirthRate", hue="IncomeGroup")
plt.show()

# %%
v4 = sns.lmplot(data = data, x = "InternetUsers", y = "BirthRate", fit_reg=False)
plt.show()
